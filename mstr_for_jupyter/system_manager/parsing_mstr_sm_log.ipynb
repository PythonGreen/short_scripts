# %%
with open('./sfazs.txt','r') as file:
    lines = file.readlines()

for row in lines:
    if 'ERROR REALIZANDO LA SIGUIENTE CONSULTA' in row:
        print(row)
# Out:
# 10/19/21 12:20:20 AM UTC 	FEEDBACK: ERROR REALIZANDO LA SIGUIENTE CONSULTA:    CREATE SECURITY FILTER 'E100195' IN PROJECT 'AZS_AT' EXPRESSION '[CIA Agente (ACT)]@COMPANY_CURRENT in ("99")'; APPLY SECURITY FILTER 'E100195' TO USER 'E100195' FOR PROJECT 'AZS_AT';
#
# 10/19/21 12:20:20 AM UTC 	FEEDBACK: ERROR REALIZANDO LA SIGUIENTE CONSULTA:    CREATE SECURITY FILTER 'E100621' IN PROJECT 'AZS_AT' EXPRESSION '[CIA Agente (ACT)]@COMPANY_CURRENT in ("99")'; APPLY SECURITY FILTER 'E100621' TO USER 'E100621' FOR PROJECT 'AZS_AT';
#
# 10/19/21 12:20:20 AM UTC 	FEEDBACK: ERROR REALIZANDO LA SIGUIENTE CONSULTA:    CREATE SECURITY FILTER 'E100728' IN PROJECT 'AZS_AT' EXPRESSION '[CIA Agente (ACT)]@COMPANY_CURRENT in ("99")'; APPLY SECURITY FILTER 'E100728' TO USER 'E100728' FOR PROJECT 'AZS_AT';
#
# ...
