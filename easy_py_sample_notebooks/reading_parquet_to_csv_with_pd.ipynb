# %%
import pyarrow.parquet as pq
import pandas as pd
from datetime import datetime, timedelta
import datetime

# %%
path = '/mnt/lnxsasdtcn/sasdata/DISCO_M/ALZFenix/local/FtpPCSas/history_azfd_nov2019_sas'
azfd_pq_file = pq.read_table(path)
azfd_df = azfd_pq_file.to_pandas()

# %%
azfd_df.head()
# Out:
#      OE CLAIM_CODE       FECHA_PROCESO                 ACCIDENT_DATE  \
# 0  AZFD  199900000 2006-02-28 23:00:00 1753-07-27 21:43:41.128654848
# 1  AZFD  199900000 2006-02-28 23:00:00 1753-07-27 21:43:41.128654848
# 2  AZFD  199900000 2006-05-31 22:00:00 1753-07-27 21:43:41.128654848
# 3  AZFD  199900000 2006-05-31 22:00:00 1753-07-27 21:43:41.128654848
# 4  AZFD  199900000 2006-08-31 22:00:00 1753-07-27 21:43:41.128654848
#
#                  REPORTING_DATE CURRENCY GUARANTEE PORTFOLIO_LOB  \
# 0 1753-07-27 21:43:41.128654848      EUR                    1020
# 1 1753-07-27 21:43:41.128654848      EUR                    1010
# 2 1753-07-27 21:43:41.128654848      EUR                    1010
# 3 1753-07-27 21:43:41.128654848      EUR                    1020
# 4 1753-07-27 21:43:41.128654848      EUR                    1020
#
#   RESERVING_LOB  G_PAID  ...  G_CASE_RECOVERY  C_PAID  C_SS     C_CASE  FLAG  \
# 0     1020_NTPL     0.0  ...              0.0     0.0   0.0  -96570.72     1
# 1     1010_NTPL     0.0  ...              0.0     0.0   0.0       0.00     1
# 2     1010_NTPL     0.0  ...              0.0     0.0   0.0       0.00     1
# 3     1020_NTPL     0.0  ...              0.0     0.0   0.0 -124949.28     1
# 4     1020_NTPL     0.0  ...              0.0     0.0   0.0 -124949.28     1
#
#    FIRST_CLOSE_DATE LATEST_CLOSE_DATE NATCAT INSTRUMENTAL CONSORCIABLE
# 0                                          0            0            0
# 1                                          0            0            0
# 2                                          0            0            0
# 3                                          0            0            0
# 4                                          0            0            0
#
# [5 rows x 22 columns]

# %%
len(azfd_df)
# Out:
# 12569358

# %%
azfd_df['FECHA_PROCESO'] = azfd_df['FECHA_PROCESO'].dt.tz_localize("GMT").dt.tz_convert('Europe/Madrid').dt.tz_localize(None)
azfd_df['ACCIDENT_DATE'] = azfd_df['ACCIDENT_DATE'].dt.tz_localize("GMT").dt.tz_convert('Europe/Madrid').dt.tz_localize(None)
azfd_df['REPORTING_DATE'] = azfd_df['REPORTING_DATE'].dt.tz_localize("GMT").dt.tz_convert('Europe/Madrid').dt.tz_localize(None)

# %%
azfd_df.head()
# Out:
#      OE CLAIM_CODE FECHA_PROCESO                 ACCIDENT_DATE  \
# 0  AZFD  199900000    2006-03-01 1753-07-27 21:28:41.128654848
# 1  AZFD  199900000    2006-03-01 1753-07-27 21:28:41.128654848
# 2  AZFD  199900000    2006-06-01 1753-07-27 21:28:41.128654848
# 3  AZFD  199900000    2006-06-01 1753-07-27 21:28:41.128654848
# 4  AZFD  199900000    2006-09-01 1753-07-27 21:28:41.128654848
#
#                  REPORTING_DATE CURRENCY GUARANTEE PORTFOLIO_LOB  \
# 0 1753-07-27 21:28:41.128654848      EUR                    1020
# 1 1753-07-27 21:28:41.128654848      EUR                    1010
# 2 1753-07-27 21:28:41.128654848      EUR                    1010
# 3 1753-07-27 21:28:41.128654848      EUR                    1020
# 4 1753-07-27 21:28:41.128654848      EUR                    1020
#
#   RESERVING_LOB  G_PAID  ...  G_CASE_RECOVERY  C_PAID  C_SS     C_CASE  FLAG  \
# 0     1020_NTPL     0.0  ...              0.0     0.0   0.0  -96570.72     1
# 1     1010_NTPL     0.0  ...              0.0     0.0   0.0       0.00     1
# 2     1010_NTPL     0.0  ...              0.0     0.0   0.0       0.00     1
# 3     1020_NTPL     0.0  ...              0.0     0.0   0.0 -124949.28     1
# 4     1020_NTPL     0.0  ...              0.0     0.0   0.0 -124949.28     1
#
#    FIRST_CLOSE_DATE LATEST_CLOSE_DATE NATCAT INSTRUMENTAL CONSORCIABLE
# 0                                          0            0            0
# 1                                          0            0            0
# 2                                          0            0            0
# 3                                          0            0            0
# 4                                          0            0            0
#
# [5 rows x 22 columns]

# %%
# filtering the df where the claim code is 339980145 using series
id_claim_339980145 = azfd_df["CLAIM_CODE"] == '339980145'
df_filtrado = azfd_df[id_claim_339980145]
df_filtrado[["CLAIM_CODE","FECHA_PROCESO","ACCIDENT_DATE","REPORTING_DATE","G_CASE"]]
# Out:
#          CLAIM_CODE FECHA_PROCESO ACCIDENT_DATE REPORTING_DATE  G_CASE
# 3268506   339980145    2000-03-01    1999-06-01     1999-06-01   13.24
# 3268507   339980145    2000-06-01    1999-06-01     1999-06-01   13.24
# 3268508   339980145    2000-09-01    1999-06-01     1999-06-01   13.24
# 3268509   339980145    2000-12-01    1999-06-01     1999-06-01    0.00
# 4022912   339980145    2000-03-01    1999-06-01     1999-06-01   49.28
# 4022913   339980145    2000-06-01    1999-06-01     1999-06-01   49.28
# 4022914   339980145    2000-09-01    1999-06-01     1999-06-01   49.28
# 4022915   339980145    2000-12-01    1999-06-01     1999-06-01    0.00
# 11377346  339980145    2000-03-01    1999-06-01     1999-06-01  132.22
# 11377347  339980145    2000-06-01    1999-06-01     1999-06-01  132.22
# 11377348  339980145    2000-09-01    1999-06-01     1999-06-01  132.22
# 11377349  339980145    2000-12-01    1999-06-01     1999-06-01    0.00

# %% [markdown]
# Converting Fenix parquet files into csv format by month

# %%
azfd_df.insert(2,'MES_PROCESO', azfd_df["FECHA_PROCESO"].dt.strftime('%Y%m') )

# %%
azfd_df.head()
# Out:
#      OE CLAIM_CODE MES_PROCESO FECHA_PROCESO                 ACCIDENT_DATE  \
# 0  AZFD  199900000      200603    2006-03-01 1753-07-27 21:28:41.128654848
# 1  AZFD  199900000      200603    2006-03-01 1753-07-27 21:28:41.128654848
# 2  AZFD  199900000      200606    2006-06-01 1753-07-27 21:28:41.128654848
# 3  AZFD  199900000      200606    2006-06-01 1753-07-27 21:28:41.128654848
# 4  AZFD  199900000      200609    2006-09-01 1753-07-27 21:28:41.128654848
#
#                  REPORTING_DATE CURRENCY GUARANTEE PORTFOLIO_LOB  \
# 0 1753-07-27 21:28:41.128654848      EUR                    1020
# 1 1753-07-27 21:28:41.128654848      EUR                    1010
# 2 1753-07-27 21:28:41.128654848      EUR                    1010
# 3 1753-07-27 21:28:41.128654848      EUR                    1020
# 4 1753-07-27 21:28:41.128654848      EUR                    1020
#
#   RESERVING_LOB  ...  G_CASE_RECOVERY  C_PAID  C_SS     C_CASE  FLAG  \
# 0     1020_NTPL  ...              0.0     0.0   0.0  -96570.72     1
# 1     1010_NTPL  ...              0.0     0.0   0.0       0.00     1
# 2     1010_NTPL  ...              0.0     0.0   0.0       0.00     1
# 3     1020_NTPL  ...              0.0     0.0   0.0 -124949.28     1
# 4     1020_NTPL  ...              0.0     0.0   0.0 -124949.28     1
#
#    FIRST_CLOSE_DATE  LATEST_CLOSE_DATE NATCAT INSTRUMENTAL CONSORCIABLE
# 0                                           0            0            0
# 1                                           0            0            0
# 2                                           0            0            0
# 3                                           0            0            0
# 4                                           0            0            0
#
# [5 rows x 23 columns]

# %%
month_check = {}

for i in range(2000,2020):
    for j in range(1,13):
        month=str(i)+"{:0>2}".format(j) # o tambien se puede usar rjust(posiciones, relleno) month=str(i)+str(j).rjust(2, '0')
        
        print("Processing: ",month)        
        dt_ini = datetime.now()
        
        df_month = azfd_df["MES_PROCESO"] == month
        
        if True in list(df_month.unique()): #o sino usar empty si estuviese vacio: df_month.empty:        
            azfd_df[df_month].to_csv(r'data/fenix_file_{}.csv'.format(month), index = None, header = True, sep = ';')
 
            dt_end = datetime.now()            
            month_check[month] = ['Yes', dt_end - dt_ini ]
            print("There are data for {}? how does it takes?".format(month), month_check[month])            
            
        else:
            
            dt_end = datetime.now()            
            month_check[month] = ['No', dt_end - dt_ini ]
            print("There are data for {}? how does it takes?".format(month), month_check[month])
# Out:
# Processing:  200001
# There are data for 200001? how does it takes? ['No', datetime.timedelta(microseconds=775300)]
# Processing:  200002
# There are data for 200002? how does it takes? ['No', datetime.timedelta(microseconds=738476)]
# Processing:  200003
# There are data for 200003? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=698279)]
# Processing:  200004
# There are data for 200004? how does it takes? ['No', datetime.timedelta(microseconds=752699)]
# Processing:  200005
# There are data for 200005? how does it takes? ['No', datetime.timedelta(microseconds=744447)]
# Processing:  200006
# There are data for 200006? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=990660)]
# Processing:  200007
# There are data for 200007? how does it takes? ['No', datetime.timedelta(microseconds=744276)]
# Processing:  200008
# There are data for 200008? how does it takes? ['No', datetime.timedelta(microseconds=752592)]
# Processing:  200009
# There are data for 200009? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=293723)]
# Processing:  200010
# There are data for 200010? how does it takes? ['No', datetime.timedelta(microseconds=769965)]
# Processing:  200011
# There are data for 200011? how does it takes? ['No', datetime.timedelta(microseconds=769598)]
# Processing:  200012
# There are data for 200012? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=984350)]
# Processing:  200101
# There are data for 200101? how does it takes? ['No', datetime.timedelta(microseconds=811403)]
# Processing:  200102
# There are data for 200102? how does it takes? ['No', datetime.timedelta(microseconds=764858)]
# Processing:  200103
# There are data for 200103? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=654960)]
# Processing:  200104
# There are data for 200104? how does it takes? ['No', datetime.timedelta(microseconds=760930)]
# Processing:  200105
# There are data for 200105? how does it takes? ['No', datetime.timedelta(microseconds=768205)]
# Processing:  200106
# There are data for 200106? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=884654)]
# Processing:  200107
# There are data for 200107? how does it takes? ['No', datetime.timedelta(microseconds=765465)]
# Processing:  200108
# There are data for 200108? how does it takes? ['No', datetime.timedelta(microseconds=768041)]
# Processing:  200109
# There are data for 200109? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=57193)]
# Processing:  200110
# There are data for 200110? how does it takes? ['No', datetime.timedelta(microseconds=774623)]
# Processing:  200111
# There are data for 200111? how does it takes? ['No', datetime.timedelta(microseconds=766121)]
# Processing:  200112
# There are data for 200112? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=71078)]
# Processing:  200201
# There are data for 200201? how does it takes? ['No', datetime.timedelta(microseconds=779051)]
# Processing:  200202
# There are data for 200202? how does it takes? ['No', datetime.timedelta(microseconds=743454)]
# Processing:  200203
# There are data for 200203? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=291767)]
# Processing:  200204
# There are data for 200204? how does it takes? ['No', datetime.timedelta(microseconds=855758)]
# Processing:  200205
# There are data for 200205? how does it takes? ['No', datetime.timedelta(microseconds=745150)]
# Processing:  200206
# There are data for 200206? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=531218)]
# Processing:  200207
# There are data for 200207? how does it takes? ['No', datetime.timedelta(microseconds=748340)]
# Processing:  200208
# There are data for 200208? how does it takes? ['No', datetime.timedelta(microseconds=787440)]
# Processing:  200209
# There are data for 200209? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=534161)]
# Processing:  200210
# There are data for 200210? how does it takes? ['No', datetime.timedelta(microseconds=825012)]
# Processing:  200211
# There are data for 200211? how does it takes? ['No', datetime.timedelta(microseconds=779494)]
# Processing:  200212
# There are data for 200212? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=729270)]
# Processing:  200301
# There are data for 200301? how does it takes? ['No', datetime.timedelta(microseconds=748109)]
# Processing:  200302
# There are data for 200302? how does it takes? ['No', datetime.timedelta(microseconds=751618)]
# Processing:  200303
# There are data for 200303? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=87404)]
# Processing:  200304
# There are data for 200304? how does it takes? ['No', datetime.timedelta(microseconds=762462)]
# Processing:  200305
# There are data for 200305? how does it takes? ['No', datetime.timedelta(microseconds=752394)]
# Processing:  200306
# There are data for 200306? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=307878)]
# Processing:  200307
# There are data for 200307? how does it takes? ['No', datetime.timedelta(microseconds=745067)]
# Processing:  200308
# There are data for 200308? how does it takes? ['No', datetime.timedelta(microseconds=751595)]
# Processing:  200309
# There are data for 200309? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=516824)]
# Processing:  200310
# There are data for 200310? how does it takes? ['No', datetime.timedelta(microseconds=826511)]
# Processing:  200311
# There are data for 200311? how does it takes? ['No', datetime.timedelta(microseconds=742966)]
# Processing:  200312
# There are data for 200312? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=765001)]
# Processing:  200401
# There are data for 200401? how does it takes? ['No', datetime.timedelta(microseconds=758426)]
# Processing:  200402
# There are data for 200402? how does it takes? ['No', datetime.timedelta(microseconds=747696)]
# Processing:  200403
# There are data for 200403? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=144014)]
# Processing:  200404
# There are data for 200404? how does it takes? ['No', datetime.timedelta(microseconds=750609)]
# Processing:  200405
# There are data for 200405? how does it takes? ['No', datetime.timedelta(microseconds=760182)]
# Processing:  200406
# There are data for 200406? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=384048)]
# Processing:  200407
# There are data for 200407? how does it takes? ['No', datetime.timedelta(microseconds=765189)]
# Processing:  200408
# There are data for 200408? how does it takes? ['No', datetime.timedelta(microseconds=772785)]
# Processing:  200409
# There are data for 200409? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=403129)]
# Processing:  200410
# There are data for 200410? how does it takes? ['No', datetime.timedelta(microseconds=748628)]
# Processing:  200411
# There are data for 200411? how does it takes? ['No', datetime.timedelta(microseconds=757748)]
# Processing:  200412
# There are data for 200412? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=594256)]
# Processing:  200501
# There are data for 200501? how does it takes? ['No', datetime.timedelta(microseconds=770577)]
# Processing:  200502
# There are data for 200502? how does it takes? ['No', datetime.timedelta(microseconds=787826)]
# Processing:  200503
# There are data for 200503? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=6166)]
# Processing:  200504
# There are data for 200504? how does it takes? ['No', datetime.timedelta(microseconds=752813)]
# Processing:  200505
# There are data for 200505? how does it takes? ['No', datetime.timedelta(microseconds=764167)]
# Processing:  200506
# There are data for 200506? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=194003)]
# Processing:  200507
# There are data for 200507? how does it takes? ['No', datetime.timedelta(microseconds=762221)]
# Processing:  200508
# There are data for 200508? how does it takes? ['No', datetime.timedelta(microseconds=789450)]
# Processing:  200509
# There are data for 200509? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=291236)]
# Processing:  200510
# There are data for 200510? how does it takes? ['No', datetime.timedelta(microseconds=751962)]
# Processing:  200511
# There are data for 200511? how does it takes? ['No', datetime.timedelta(microseconds=767501)]
# Processing:  200512
# There are data for 200512? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=617397)]
# Processing:  200601
# There are data for 200601? how does it takes? ['No', datetime.timedelta(microseconds=756089)]
# Processing:  200602
# There are data for 200602? how does it takes? ['No', datetime.timedelta(microseconds=768131)]
# Processing:  200603
# There are data for 200603? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=244150)]
# Processing:  200604
# There are data for 200604? how does it takes? ['No', datetime.timedelta(microseconds=825733)]
# Processing:  200605
# There are data for 200605? how does it takes? ['No', datetime.timedelta(microseconds=764753)]
# Processing:  200606
# There are data for 200606? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=557276)]
# Processing:  200607
# There are data for 200607? how does it takes? ['No', datetime.timedelta(microseconds=765722)]
# Processing:  200608
# There are data for 200608? how does it takes? ['No', datetime.timedelta(microseconds=750380)]
# Processing:  200609
# There are data for 200609? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=854174)]
# Processing:  200610
# There are data for 200610? how does it takes? ['No', datetime.timedelta(microseconds=752396)]
# Processing:  200611
# There are data for 200611? how does it takes? ['No', datetime.timedelta(microseconds=752597)]
# Processing:  200612
# There are data for 200612? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=233200)]
# Processing:  200701
# There are data for 200701? how does it takes? ['No', datetime.timedelta(microseconds=773055)]
# Processing:  200702
# There are data for 200702? how does it takes? ['No', datetime.timedelta(microseconds=764804)]
# Processing:  200703
# There are data for 200703? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=608909)]
# Processing:  200704
# There are data for 200704? how does it takes? ['No', datetime.timedelta(microseconds=761612)]
# Processing:  200705
# There are data for 200705? how does it takes? ['No', datetime.timedelta(microseconds=750299)]
# Processing:  200706
# There are data for 200706? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=936501)]
# Processing:  200707
# There are data for 200707? how does it takes? ['No', datetime.timedelta(microseconds=766330)]
# Processing:  200708
# There are data for 200708? how does it takes? ['No', datetime.timedelta(microseconds=761580)]
# Processing:  200709
# There are data for 200709? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=350437)]
# Processing:  200710
# There are data for 200710? how does it takes? ['No', datetime.timedelta(microseconds=746710)]
# Processing:  200711
# There are data for 200711? how does it takes? ['No', datetime.timedelta(microseconds=743770)]
# Processing:  200712
# There are data for 200712? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=763937)]
# Processing:  200801
# There are data for 200801? how does it takes? ['No', datetime.timedelta(microseconds=756007)]
# Processing:  200802
# There are data for 200802? how does it takes? ['No', datetime.timedelta(microseconds=750465)]
# Processing:  200803
# There are data for 200803? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=745294)]
# Processing:  200804
# There are data for 200804? how does it takes? ['No', datetime.timedelta(microseconds=777611)]
# Processing:  200805
# There are data for 200805? how does it takes? ['No', datetime.timedelta(microseconds=753844)]
# Processing:  200806
# There are data for 200806? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=198535)]
# Processing:  200807
# There are data for 200807? how does it takes? ['No', datetime.timedelta(microseconds=767945)]
# Processing:  200808
# There are data for 200808? how does it takes? ['No', datetime.timedelta(microseconds=763949)]
# Processing:  200809
# There are data for 200809? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=606347)]
# Processing:  200810
# There are data for 200810? how does it takes? ['No', datetime.timedelta(microseconds=760966)]
# Processing:  200811
# There are data for 200811? how does it takes? ['No', datetime.timedelta(microseconds=756780)]
# Processing:  200812
# There are data for 200812? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=47175)]
# Processing:  200901
# There are data for 200901? how does it takes? ['No', datetime.timedelta(microseconds=754678)]
# Processing:  200902
# There are data for 200902? how does it takes? ['No', datetime.timedelta(microseconds=753433)]
# Processing:  200903
# There are data for 200903? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=765081)]
# Processing:  200904
# There are data for 200904? how does it takes? ['No', datetime.timedelta(microseconds=752890)]
# Processing:  200905
# There are data for 200905? how does it takes? ['No', datetime.timedelta(microseconds=761133)]
# Processing:  200906
# There are data for 200906? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=266096)]
# Processing:  200907
# There are data for 200907? how does it takes? ['No', datetime.timedelta(microseconds=777753)]
# Processing:  200908
# There are data for 200908? how does it takes? ['No', datetime.timedelta(microseconds=758795)]
# Processing:  200909
# There are data for 200909? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=743462)]
# Processing:  200910
# There are data for 200910? how does it takes? ['No', datetime.timedelta(microseconds=748271)]
# Processing:  200911
# There are data for 200911? how does it takes? ['No', datetime.timedelta(microseconds=761847)]
# Processing:  200912
# There are data for 200912? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=296252)]
# Processing:  201001
# There are data for 201001? how does it takes? ['No', datetime.timedelta(microseconds=748667)]
# Processing:  201002
# There are data for 201002? how does it takes? ['No', datetime.timedelta(microseconds=770634)]
# Processing:  201003
# There are data for 201003? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=28011)]
# Processing:  201004
# There are data for 201004? how does it takes? ['No', datetime.timedelta(microseconds=766198)]
# Processing:  201005
# There are data for 201005? how does it takes? ['No', datetime.timedelta(microseconds=748887)]
# Processing:  201006
# There are data for 201006? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=808791)]
# Processing:  201007
# There are data for 201007? how does it takes? ['No', datetime.timedelta(microseconds=820441)]
# Processing:  201008
# There are data for 201008? how does it takes? ['No', datetime.timedelta(microseconds=778374)]
# Processing:  201009
# There are data for 201009? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=352045)]
# Processing:  201010
# There are data for 201010? how does it takes? ['No', datetime.timedelta(microseconds=790840)]
# Processing:  201011
# There are data for 201011? how does it takes? ['No', datetime.timedelta(microseconds=745415)]
# Processing:  201012
# There are data for 201012? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=650175)]
# Processing:  201101
# There are data for 201101? how does it takes? ['No', datetime.timedelta(microseconds=793079)]
# Processing:  201102
# There are data for 201102? how does it takes? ['No', datetime.timedelta(microseconds=770393)]
# Processing:  201103
# There are data for 201103? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=976065)]
# Processing:  201104
# There are data for 201104? how does it takes? ['No', datetime.timedelta(microseconds=755732)]
# Processing:  201105
# There are data for 201105? how does it takes? ['No', datetime.timedelta(microseconds=778967)]
# Processing:  201106
# There are data for 201106? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=517375)]
# Processing:  201107
# There are data for 201107? how does it takes? ['No', datetime.timedelta(microseconds=763444)]
# Processing:  201108
# There are data for 201108? how does it takes? ['No', datetime.timedelta(microseconds=758877)]
# Processing:  201109
# There are data for 201109? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=947625)]
# Processing:  201110
# There are data for 201110? how does it takes? ['No', datetime.timedelta(microseconds=747202)]
# Processing:  201111
# There are data for 201111? how does it takes? ['No', datetime.timedelta(microseconds=754507)]
# Processing:  201112
# There are data for 201112? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=578592)]
# Processing:  201201
# There are data for 201201? how does it takes? ['No', datetime.timedelta(microseconds=759786)]
# Processing:  201202
# There are data for 201202? how does it takes? ['No', datetime.timedelta(microseconds=768959)]
# Processing:  201203
# There are data for 201203? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=184181)]
# Processing:  201204
# There are data for 201204? how does it takes? ['No', datetime.timedelta(microseconds=804482)]
# Processing:  201205
# There are data for 201205? how does it takes? ['No', datetime.timedelta(microseconds=804221)]
# Processing:  201206
# There are data for 201206? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=700998)]
# Processing:  201207
# There are data for 201207? how does it takes? ['No', datetime.timedelta(microseconds=848736)]
# Processing:  201208
# There are data for 201208? how does it takes? ['No', datetime.timedelta(microseconds=765410)]
# Processing:  201209
# There are data for 201209? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=228690)]
# Processing:  201210
# There are data for 201210? how does it takes? ['No', datetime.timedelta(microseconds=769131)]
# Processing:  201211
# There are data for 201211? how does it takes? ['No', datetime.timedelta(microseconds=754929)]
# Processing:  201212
# There are data for 201212? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=695618)]
# Processing:  201301
# There are data for 201301? how does it takes? ['No', datetime.timedelta(microseconds=766128)]
# Processing:  201302
# There are data for 201302? how does it takes? ['No', datetime.timedelta(microseconds=768592)]
# Processing:  201303
# There are data for 201303? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=191530)]
# Processing:  201304
# There are data for 201304? how does it takes? ['No', datetime.timedelta(microseconds=777273)]
# Processing:  201305
# There are data for 201305? how does it takes? ['No', datetime.timedelta(microseconds=779250)]
# Processing:  201306
# There are data for 201306? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=756231)]
# Processing:  201307
# There are data for 201307? how does it takes? ['No', datetime.timedelta(microseconds=758090)]
# Processing:  201308
# There are data for 201308? how does it takes? ['No', datetime.timedelta(microseconds=746398)]
# Processing:  201309
# There are data for 201309? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=445164)]
# Processing:  201310
# There are data for 201310? how does it takes? ['No', datetime.timedelta(microseconds=746322)]
# Processing:  201311
# There are data for 201311? how does it takes? ['No', datetime.timedelta(microseconds=748725)]
# Processing:  201312
# There are data for 201312? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=67370)]
# Processing:  201401
# There are data for 201401? how does it takes? ['Yes', datetime.timedelta(seconds=1, microseconds=945186)]
# Processing:  201402
# There are data for 201402? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=154447)]
# Processing:  201403
# There are data for 201403? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=348368)]
# Processing:  201404
# There are data for 201404? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=599114)]
# Processing:  201405
# There are data for 201405? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=749264)]
# Processing:  201406
# There are data for 201406? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=908716)]
# Processing:  201407
# There are data for 201407? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=163899)]
# Processing:  201408
# There are data for 201408? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=293244)]
# Processing:  201409
# There are data for 201409? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=815254)]
# Processing:  201410
# There are data for 201410? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=950650)]
# Processing:  201411
# There are data for 201411? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=153514)]
# Processing:  201412
# There are data for 201412? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=161200)]
# Processing:  201501
# There are data for 201501? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=95063)]
# Processing:  201502
# There are data for 201502? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=257813)]
# Processing:  201503
# There are data for 201503? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=474976)]
# Processing:  201504
# There are data for 201504? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=802784)]
# Processing:  201505
# There are data for 201505? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=941568)]
# Processing:  201506
# There are data for 201506? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=514283)]
# Processing:  201507
# There are data for 201507? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=20274)]
# Processing:  201508
# There are data for 201508? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=104651)]
# Processing:  201509
# There are data for 201509? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=359379)]
# Processing:  201510
# There are data for 201510? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=925461)]
# Processing:  201511
# There are data for 201511? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=155920)]
# Processing:  201512
# There are data for 201512? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=437261)]
# Processing:  201601
# There are data for 201601? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=76750)]
# Processing:  201602
# There are data for 201602? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=267941)]
# Processing:  201603
# There are data for 201603? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=503005)]
# Processing:  201604
# There are data for 201604? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=704946)]
# Processing:  201605
# There are data for 201605? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=929088)]
# Processing:  201606
# There are data for 201606? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=171476)]
# Processing:  201607
# There are data for 201607? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=417018)]
# Processing:  201608
# There are data for 201608? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=620748)]
# Processing:  201609
# There are data for 201609? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=868772)]
# Processing:  201610
# There are data for 201610? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=222099)]
# Processing:  201611
# There are data for 201611? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=404355)]
# Processing:  201612
# There are data for 201612? how does it takes? ['Yes', datetime.timedelta(seconds=5, microseconds=7918)]
# Processing:  201701
# There are data for 201701? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=74300)]
# Processing:  201702
# There are data for 201702? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=419117)]
# Processing:  201703
# There are data for 201703? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=541520)]
# Processing:  201704
# There are data for 201704? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=872582)]
# Processing:  201705
# There are data for 201705? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=106254)]
# Processing:  201706
# There are data for 201706? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=468127)]
# Processing:  201707
# There are data for 201707? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=611408)]
# Processing:  201708
# There are data for 201708? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=839296)]
# Processing:  201709
# There are data for 201709? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=117094)]
# Processing:  201710
# There are data for 201710? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=397109)]
# Processing:  201711
# There are data for 201711? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=553106)]
# Processing:  201712
# There are data for 201712? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=838503)]
# Processing:  201801
# There are data for 201801? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=133865)]
# Processing:  201802
# There are data for 201802? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=404800)]
# Processing:  201803
# There are data for 201803? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=654992)]
# Processing:  201804
# There are data for 201804? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=872955)]
# Processing:  201805
# There are data for 201805? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=145365)]
# Processing:  201806
# There are data for 201806? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=466420)]
# Processing:  201807
# There are data for 201807? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=589702)]
# Processing:  201808
# There are data for 201808? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=841821)]
# Processing:  201809
# There are data for 201809? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=206342)]
# Processing:  201810
# There are data for 201810? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=254401)]
# Processing:  201811
# There are data for 201811? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=608413)]
# Processing:  201812
# There are data for 201812? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=901596)]
# Processing:  201901
# There are data for 201901? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=306196)]
# Processing:  201902
# There are data for 201902? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=405205)]
# Processing:  201903
# There are data for 201903? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=719066)]
# Processing:  201904
# There are data for 201904? how does it takes? ['Yes', datetime.timedelta(seconds=2, microseconds=908594)]
# Processing:  201905
# There are data for 201905? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=103358)]
# Processing:  201906
# There are data for 201906? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=440563)]
# Processing:  201907
# There are data for 201907? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=514258)]
# Processing:  201908
# There are data for 201908? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=707462)]
# Processing:  201909
# There are data for 201909? how does it takes? ['Yes', datetime.timedelta(seconds=3, microseconds=865095)]
# Processing:  201910
# There are data for 201910? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=168189)]
# Processing:  201911
# There are data for 201911? how does it takes? ['Yes', datetime.timedelta(seconds=4, microseconds=391211)]
# Processing:  201912
# There are data for 201912? how does it takes? ['No', datetime.timedelta(microseconds=744097)]

# %%
print("Total time:", sum([i[1] for i in month_check.values()], datetime.timedelta()), "\n",  
      "Month processed", len(month_check) ,   "\n",  
      "Month with data", len([i for i in month_check.values() if i[0]=='Yes']) ,"\n",  
      "Month with no data", len([i for i in month_check.values() if i[0]=='No'])
     )
# Out:
# Total time: 0:07:26.894360
#  Month processed 240
#  Month with data 127
#  Month with no data 113

# %%
# Out:
# '/home/e106064'
