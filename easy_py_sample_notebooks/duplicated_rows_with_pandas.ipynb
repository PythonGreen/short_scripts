# %%
import pandas
import os

# %%
pandas.__file__
os.__file__
# Out:
# '/usr/lib64/python3.6/os.py'

# %%
os.listdir('/mnt/lnxsasdtcn/sas/APPSAS/RE_DESARROLLO/PAD/202103')
# Out:
# ['SHRVK862_01.TXT',
#  'SHRVK863_01.TXT',
#  'SHRVK873_01.TXT',
#  'SHRVK881_01.TXT',
#  'SHRVK883_01.TXT',
#  'SHRVK858_01.TXT',
#  'SHRVK859_01.TXT']

# %%
import pandas as pd

tb_campos = pd.read_sas('/mnt/lnxsasdtcn/sas/APPSAS/SOURCE/campos.sas7bdat')

# %%
import pandas as pd
tb_campos = pd.read_csv("/mnt/lnxsasdtcn/sas/APPSAS/RE_DESARROLLO/PAD/202103/SHRBK187_01.TXT", sep='#',engine='python', encoding = "ISO-8859-1" , header=None)

# %%
tb_campos[tb_campos.duplicated()]
# Out:
#       0             1   2                                                  3   \
# 4700  JV  116287843010  30  Anulacion sin reemision                       ...
# 4702  JV  116287853910  30  Anulacion sin reemision                       ...
# 5073  JV  116687984810  30  Anulacion sin reemision                       ...
#
#                   4   5           6     7                     8    9   ... 53  \
# 4700  11650000533430  13  HG_GAMA     1165  1165 SEG VIV REM EXT  EUR  ...  6
# 4702  11650000533430  13  HG_GAMA     1165  1165 SEG VIV REM EXT  EUR  ...  6
# 5073  11650000514182  15  HG_GAMA     1165  1165 SEG VIV REM EXT  EUR  ...  6
#
#                                                      54                 55  \
# 4700  BBVA OPERADOR BANCASEGUROS                    ...   000000000000,000
# 4702  BBVA OPERADOR BANCASEGUROS                    ...  -000000000012,620
# 5073  BBVA OPERADOR BANCASEGUROS                    ...  -000000000075,400
#
# ...

# %%
#116287843010
tb_campos[tb_campos[:][1]==116287843010]
# Out:
#       0             1   2                                                  3   \
# 4699  JV  116287843010  30  Anulacion sin reemision                       ...
# 4700  JV  116287843010  30  Anulacion sin reemision                       ...
#
#                   4   5           6     7                     8    9   ... 53  \
# 4699  11650000533430  13  HG_GAMA     1165  1165 SEG VIV REM EXT  EUR  ...  6
# 4700  11650000533430  13  HG_GAMA     1165  1165 SEG VIV REM EXT  EUR  ...  6
#
#                                                      54                 55  \
# 4699  BBVA OPERADOR BANCASEGUROS                    ...   000000000000,000
# 4700  BBVA OPERADOR BANCASEGUROS                    ...   000000000000,000
#
#                      56          57  \
# 4699   000000000000,000  53063112L
# 4700   000000000000,000  53063112L
#
#                                                      58  59  60  \
# 4699  JIMENEZ VENTEO, SERGIO                        ...   1
# ...

# %%
tb_campos[tb_campos[:][1]==116287843010].to_csv('duplicados.csv')
